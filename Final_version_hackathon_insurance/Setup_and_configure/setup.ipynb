-- %%
create catalog if not exists primeinsurance_analytics;
use catalog primeinsurance_analytics

-- %%
create schema if not exists bronze;
use bronze;
create schema if not exists silver;
use silver;
create schema if not exists gold;
use gold;
